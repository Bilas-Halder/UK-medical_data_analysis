# %%
import numpy as np
import pandas as pd

# %%
national = np.array([-0.39, -0.42, -0.29, -0.76,  0.34, -0.53,  0.67, -0.53, -0.19, -0.25,  0.33, -0.06, -0.01, -0.03])
own = np.array([-0.16, -0.29,  0.18,   1.2, -1.22,  1.46, -0.15, -0.26,  1.21,  -0.6, -0.84,  1.43,  0.98,  0.05])
point_label = np.array(["M1", "M2", "M3", "M4", "M5", "M6", "M7", "D1", "D2", "D3", "D4", "D5", "D6", "D7"])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data within the range -4 to 4
x = national
y = own

# Determine the quadrant for each data point
quadrants = []
for x_val, y_val in zip(x, y):
    if x_val >= 0 and y_val >= 0:
        quadrants.append(1)  # First quadrant
    elif x_val < 0 and y_val >= 0:
        quadrants.append(2)  # Second quadrant
    elif x_val < 0 and y_val < 0:
        quadrants.append(3)  # Third quadrant
    else:
        quadrants.append(4)  # Fourth quadrant

# Assign colors based on the quadrant
colors = ['#c1311c', '#ffbf00','#27a874', '#ffbf00']
scatter_colors = [colors[q - 1] for q in quadrants]

# Create the scatter plot
plt.scatter(x, y, c=scatter_colors)

# Add vertical and horizontal lines
plt.axvline(x=0, color='#08807c', linestyle='--')  # Vertical line at x=0
plt.axhline(y=0, color='#08807c', linestyle='--')  # Horizontal line at y=0



plt.xlim(-4, 4)
plt.ylim(-4, 4)




for (xi, yi, pl) in zip(x, y, point_label ):
    plt.text(xi, yi, "   "+pl+"   ", va='top', ha='left', fontweight="semibold")




# Add labels and title
plt.xlabel('SD away from National avg')
plt.ylabel('SD away from Own avg')
plt.title('Comparison against National and Own avg for Northampton General Hospital NHS Trust', fontsize=18)

plt.figure(figsize=(16,7))

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from matplotlib.patches import Rectangle

# Generate random data within the range -4 to 4

x = national
y = own

# Determine the quadrant for each data point
quadrants = []
for x_val, y_val in zip(x, y):
    if x_val >= 0 and y_val >= 0:
        quadrants.append(1)  # First quadrant
    elif x_val < 0 and y_val >= 0:
        quadrants.append(2)  # Second quadrant
    elif x_val < 0 and y_val < 0:
        quadrants.append(3)  # Third quadrant
    else:
        quadrants.append(4)  # Fourth quadrant

# Assign colors based on the quadrant
# colors = ['yellow', 'green', 'blue', 'orange']
colors = ['#c1311c', '#ffbf00','#0b784c', '#ffbf00']
scatter_colors = [colors[q - 1] for q in quadrants]

# Create a DataFrame with the data
data = {'x': x, 'y': y, 'quadrant': quadrants}
df = pd.DataFrame(data)

# Set the default seaborn style
sns.set(rc={'figure.figsize':(16,7)})

ax = plt.gca()

# Add rectangle patches with background color
rect1 = Rectangle((0, 0), 4, 4, linewidth=1, edgecolor='r', facecolor='#cc3f2b')
rect2 = Rectangle((-4, -4), 4, 4, linewidth=1, edgecolor='g', facecolor='#27a874')
rect3 = Rectangle((-4, 0), 4, 4, linewidth=1, edgecolor='y', facecolor='#ffbf00')
rect4 = Rectangle((0, -4), 4, 4, linewidth=1, edgecolor='y', facecolor='#ffbf00')

# Add the rectangles to the plot
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)

# Create the scatter plot using seaborn
# sns.scatterplot(data=df, x='x', y='y',  legend=False)

colors = ['black','black','black','black']
scatter_colors = [colors[q - 1] for q in quadrants]

# Create the scatter plot
plt.scatter(x, y, c=scatter_colors)

# Add vertical and horizontal lines
plt.axvline(x=0, color='black', linestyle='--')  # Vertical line at x=0
plt.axhline(y=0, color='black', linestyle='--')  # Horizontal line at y=0



# Set plot limits
plt.xlim(-4, 4)
plt.ylim(-4, 4)




for (xi, yi, pl) in zip(x, y, point_label ):
    plt.text(xi, yi, "   "+pl+"   ", va='top', ha='left', color="white", fontweight="semibold")


# Add labels and title
# Add labels and title
plt.xlabel('SD away from National avg')
plt.ylabel('SD away from Own avg')
plt.title('Comparison against National and Own avg for Northampton General Hospital NHS Trust', fontsize=18)

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Generate some random data for the scatter plot
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create the scatter plot using seaborn
sns.scatterplot(x, y)

# Get the current axis
ax = plt.gca()

# Add rectangle patches with background color
rect1 = Rectangle((2, 3), 1, 2, linewidth=1, edgecolor='r', facecolor='#58e8ae50')
# rect2 = Rectangle((4, 6), 1, 2, linewidth=1, edgecolor='g', facecolor='lightgreen')
# rect3 = Rectangle((3, 8), 1, 1, linewidth=1, edgecolor='b', facecolor='lightblue')
# rect4 = Rectangle((1, 7), 1, 3, linewidth=1, edgecolor='y', facecolor='gold')

# Add the rectangles to the plot
ax.add_patch(rect1)
# ax.add_patch(rect2)
# ax.add_patch(rect3)
# ax.add_patch(rect4)

# Display the plot
plt.show()
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd

# %%
daily_data = pd.read_excel("./data/Daily Average Data.xlsx")
daily_data["Date"] = pd.to_datetime(daily_data["Date"], errors='coerce')
daily_data["Date"] = pd.to_datetime(daily_data["Date"], format="%Y-%m")

# %%
Provider_Codes = daily_data["Provider_Code"].unique()
Provider_Codes
# Out:
# array(['R0A', 'R0B', 'R1H', 'R1K', 'RA2', 'RA7', 'RA9', 'RAE', 'RAJ',
#        'RAL', 'RAP', 'RAS', 'RAX', 'RBD', 'RBK', 'RBL', 'RBN', 'RBT',
#        'RCB', 'RCD', 'RCF', 'RCX', 'RD1', 'RN3', 'RD8', 'RNZ', 'RRK',
#        'RDE', 'RTH', 'RHW', 'RGN', 'RJR', 'RJN', 'REM', 'REF', 'RLT',
#        'RJC', 'RKB', 'RR7', 'RNN', 'RTF', 'RTD', 'RH8', 'RF4', 'RQX',
#        'RTE', 'RMC', 'RFF', 'RM3', 'RMP', 'RRF', 'RN5', 'RHM', 'RFS',
#        'RLQ', 'RQW', 'RJL', 'RTG', 'RN7', 'RGP', 'RPA', 'RH5', 'RM1',
#        'RRV', 'RKE', 'RHQ', 'RNS', 'RJ1', 'RK5', 'RJ2', 'RJZ', 'RJ6',
#        'RJ7', 'RP5', 'RJE', 'RNA', 'RL4', 'RR8', 'RTK', 'RTP', 'RTR',
#        'RTX', 'RVJ', 'RVR', 'RVV', 'RVY', 'RWA', 'RWD', 'RWE', 'RWF',
#        'RWG', 'RWH', 'RWJ', 'RWP', 'RWW', 'RWY', 'RXC', 'RXK', 'RXL',
#        'RXN', 'RXP', 'RXQ', 'RXR', 'RXW', 'RYR'], dtype=object)

# %%
def get_daily_comp_with_itself(grouped_Provider,provider):
    selected_Provider = grouped_Provider.get_group(provider)

    sample_std = selected_Provider.std(ddof=0)
    sample_mean = selected_Provider.mean()
    selected_Provider = selected_Provider[selected_Provider["Date"]=="2023-03-31"]

    selected_Provider = selected_Provider.set_index("Provider_Code")

    features = [
        "Daily_Average_Staff_Absence",
        "Arriving_by_ambulance",
        "Time_Lost_to_Ambulance_Handover_Delays_Hours",
        "Monthly_Avg_Patients_who_no_longer_meet_the_criteria_to_reside",
        "Daily_Avg_Bed_Occupancy>7 days",
        "Daily_Avg_Bed_Occupancy>14 days",
        "Daily_Avg_Bed_Occupancy>21 days"
    ]
    std_away = (selected_Provider[features] -
                sample_mean[features])/sample_std[features]
    std_away = std_away.astype(float).round(2)
    
    # std_away = std_away + (std_away > 0)
    # std_away = (std_away*10)//10
    # std_away[std_away >= 5] = 4
    # std_away[std_away <= -5] = -4


    return std_away

# %%
grouped_Provider = daily_data.groupby('Provider_Code')

new = get_daily_comp_with_itself(grouped_Provider,"R0A")


for provider in Provider_Codes:
    std_away = get_daily_comp_with_itself(grouped_Provider,provider)
    new = pd.concat([new, std_away])

new.to_excel("daily_avg_dec_to_mar.xlsx")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2419044687.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2419044687.py:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2419044687.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()
# ...

# %%
new
# Out:
#                Daily_Average_Staff_Absence  Arriving_by_ambulance  \
# Provider_Code
# R0A                                  -1.14                   1.21
# R0A                                  -1.14                   1.21
# R0B                                  -1.26                   1.29
# R1H                                  -1.03                   0.52
# R1K                                  -0.83                   0.87
# ...                                    ...                    ...
# RXP                                  -1.11                   1.07
# RXQ                                  -0.87                   1.41
# RXR                                  -0.73                   0.98
# RXW                                  -0.30                  -1.33
# RYR                                   0.69                   1.04
#
#                Time_Lost_to_Ambulance_Handover_Delays_Hours  \
# Provider_Code
# R0A                                                   -0.71
# ...

# %% [markdown]
# ## daily national avg

# %%
def get_daily_avg_mar_all_hospital(date="2023-03-31"):

    daily_data = pd.read_excel("./data/Daily Average Data.xlsx")

    daily_data["Date"] = pd.to_datetime(daily_data["Date"], errors='coerce')

    daily_data["Date"] = pd.to_datetime(daily_data["Date"], format="%Y-%m")

    x = daily_data.groupby('Date')

    selected_Provider = x.get_group(date)
    selected_Provider.head()

    sample_std = selected_Provider.std(ddof=0)
    sample_mean = selected_Provider.mean()
    
    selected_Provider = selected_Provider.set_index("Provider_Code")
    features = [
        "Daily_Average_Staff_Absence",
        "Arriving_by_ambulance",
        "Time_Lost_to_Ambulance_Handover_Delays_Hours",
        "Monthly_Avg_Patients_who_no_longer_meet_the_criteria_to_reside",
        "Daily_Avg_Bed_Occupancy>7 days",
        "Daily_Avg_Bed_Occupancy>14 days",
        "Daily_Avg_Bed_Occupancy>21 days"
    ]

    std_away = (selected_Provider[features] -
                sample_mean[features])/sample_std[features]
    
    
    std_away = std_away.astype(float).round(2)
    
    # std_away = std_away + (std_away > 0)
    # std_away = (std_away*10)//10

    # std_away[std_away >= 5] = 4
    # std_away[std_away <= -5] = -4

    return std_away

# %%
new = get_daily_avg_mar_all_hospital()


new.to_excel("daily_avg_mar_all_hospital.xlsx")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\360242256.py:14: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\360242256.py:15: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\360242256.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()

# %% [markdown]
# # monthly national

# %%
def get_march_all_hospital(month="2023-03-31"):
    monthly_data = pd.read_excel("./data/Monthly Data.xlsx")

    monthly_data["Month"] = pd.to_datetime(
        monthly_data["Month"], errors='coerce')

    monthly_data["Month"] = pd.to_datetime(
        monthly_data["Month"], format="%Y-%m")

    x = monthly_data.groupby('Month')

    selected_Provider = x.get_group(month)
    selected_Provider.head()

    sample_std = selected_Provider.std(ddof=0)
    sample_mean = selected_Provider.mean()
    selected_Provider = selected_Provider.set_index("Provider_Code")

    features = [
        "AandE_Attends_Type1",
        "Attends_Under_4Hrs_Arr_To_Adm_Tfr_Disch_Type1",
        "Attends_Over_4Hrs_Arr_To_Adm_Tfr_Disch_Type1",
        "Emerg_Adms_Via_Type1",
        "Emerg_Adms_Not_Via_AandE",
        "Dec_To_Adm_4_to_12Hrs",
        "Dec_To_Adm_Over_12Hrs",
    ]

    std_away = (selected_Provider[features] -
                sample_mean[features])/sample_std[features]
    
    
    std_away = std_away.astype(float).round(2)


    # std_away = std_away + (std_away > 0)
    # std_away = (std_away*10)//10

    return std_away

# %%
get_march_all_hospital()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:16: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()
#                AandE_Attends_Type1  \
# Provider_Code
# R0A                           3.09
# ...

# %%
new = get_march_all_hospital()


new.to_excel("monthly Mar '23 All Hospital.xlsx")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\3791830513.py:16: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()

# %% [markdown]
# ## monthly own

# %%
def get_provider_monthly_insight(provider_code="R0A"):
    # getting the data
    monthly_data = pd.read_excel("./data/Monthly Data.xlsx")

    # changing month to datetime
    monthly_data["Month"] = pd.to_datetime(
        monthly_data["Month"], errors='coerce')

    # groupby provider_code to select provider
    x = monthly_data.groupby('Provider_Code')

    # selecting provider / hospital
    selected_Provider = x.get_group(provider_code)

    sample_std = selected_Provider.std(ddof=0)
    sample_mean = selected_Provider.mean()

    
    selected_Provider = selected_Provider[selected_Provider["Month"]=="2023-03-31"]
    selected_Provider = selected_Provider.set_index("Provider_Code")

    features = [
        "AandE_Attends_Type1",
        "Attends_Under_4Hrs_Arr_To_Adm_Tfr_Disch_Type1",
        "Attends_Over_4Hrs_Arr_To_Adm_Tfr_Disch_Type1",
        "Emerg_Adms_Via_Type1",
        "Emerg_Adms_Not_Via_AandE",
        "Dec_To_Adm_4_to_12Hrs",
        "Dec_To_Adm_Over_12Hrs",
    ]

    std_away = (selected_Provider[features] -
                sample_mean[features])/sample_std[features]
    
    std_away = std_away.astype(float).round(2)

    # std_away = std_away + (std_away > 0)
    # std_away = (std_away*10)//10
    return std_away

# %%
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14420\2374120971.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14420\2374120971.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_14420\2374120971.py:16: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()
#               AandE_Attends_Type1  \
# Provider_Code
# R0A                          -1.0
#
# ...

# %%
new = get_provider_monthly_insight()


for provider in Provider_Codes:
    std_away = get_provider_monthly_insight(provider)
    new = pd.concat([new, std_away])

# new.to_excel("daily_avg_dec_to_mar.xlsx")
new
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2423483449.py:15: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_std = selected_Provider.std(ddof=0)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2423483449.py:16: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   sample_mean = selected_Provider.mean()
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7316\2423483449.py:16: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sample_mean = selected_Provider.mean()
# ...

# %%
new.to_excel("monthly_comparison_with_own_12_month.xlsx")
new
# Out:
#                AandE_Attends_Type1  \
# Provider_Code
# R0A                          -0.19
# R0A                          -0.19
# R0B                           0.11
# R1H                          -0.18
# R1K                           1.71
# ...                            ...
# RXP                           1.24
# RXQ                           1.13
# RXR                           0.72
# RXW                          -0.27
# RYR                           2.64
#
#                Attends_Under_4Hrs_Arr_To_Adm_Tfr_Disch_Type1  \
# Provider_Code
# R0A                                                     0.15
# R0A                                                     0.15
# R0B                                                    -0.09
# R1H                                                    -0.36
# R1K                                                     1.04
# ...                                                      ...
# RXP                                                     0.65
# ...
